# %%
import pandas as pd 
import matplotlib.pyplot as plt
import datetime
import numpy as np
import os
import sys

import pylab as pl

# %%
filepath = '/teams/DSC180A_FA20_A00/b05vpnxray/group2_data/data'
data = os.listdir(filepath)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-2858c8851f70> in <module>
#       1 filepath = '/teams/DSC180A_FA20_A00/b05vpnxray/group2_data/data'
# ----> 2 data = os.listdir(filepath)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/teams/DSC180A_FA20_A00/b05vpnxray/group2_data/data'

# %%
def label_identifyer(x):
    if 'netflix' in x:
        return 'Netflix'
    if 'prime' in x:
        return 'Amazon Prime'
    if 'youtube' in x:
        return 'Youtube'
    else:
        return 'Other'

# %%
nf_a=pd.read_csv("/users/mollyrowland/downloads/GitHub/network-stats/mhrowlan-netflix-1x-vpn-mac-clean-20210104.csv")
nf_b=pd.read_csv("/users/mollyrowland/downloads/GitHub/network-stats/mhrowlan-netflix-1x-vpn-mac-clean-20210104a.csv")
yt_a=pd.read_csv("/users/mollyrowland/downloads/GitHub/network-stats/mhrowlan-youtube-1x-vpn-mac-clean-20210105.csv")
yt_b=pd.read_csv("/users/mollyrowland/downloads/GitHub/network-stats/mhrowlan-youtube-1x-vpn-mac-clean-20210105a.csv")
ap_a=pd.read_csv("/users/mollyrowland/downloads/GitHub/network-stats/arv020_amazonprime_1080p_1x_vpn_mac_clean_1.csv")
ap_b=pd.read_csv("/users/mollyrowland/downloads/GitHub/network-stats/arv020_amazonprime_1080p_1x_vpn_mac_clean_2.csv")

# %%
#convert all information into MB so it is more understandable
mb=1000000

# %% [markdown]
# the two netflix datas were recorded sequentially, so a was at the start of a video and b was not. From this we can see the larger data load at the begining for netflix and the more consistent load of data throughoutm all below 1.5 MB

# %%
plt.plot(nf_a['2->1Bytes']/mb)
plt.plot(nf_b['2->1Bytes']/mb)
plt.xlabel("Index")
plt.ylabel("MB")
plt.title("Download Rates of Netflix")
# Out:
# Text(0.5, 1.0, 'Download Rates of Netflix')

# %%
nf_a['2->1Bytes'][1:30]/mb
# Out:
# 1     0.000000
# 2     0.000545
# 3     0.000000
# 4     0.006316
# 5     0.000000
# 6     1.237363
# 7     2.426757
# 8     0.000000
# 9     0.000000
# 10    1.505029
# 11    0.000000
# 12    0.000000
# 13    0.000000
# 14    0.000000
# 15    1.960521
# 16    0.000000
# 17    0.000000
# 18    0.000052
# 19    0.000000
# 20    0.000000
# 21    0.000000
# 22    0.000000
# 23    0.000000
# 24    0.000000
# 25    2.419098
# 26    0.000000
# 27    0.000000
# 28    0.000000
# 29    0.000000
# Name: 2->1Bytes, dtype: float64

# %%
nf_a['2->1Bytes'].loc[318:330]/mb
# Out:
# 318    0.000000
# 319    0.703837
# 320    0.000000
# 321    0.000000
# 322    0.711359
# 323    0.000000
# 324    0.000000
# 325    0.000236
# 326    0.000000
# 327    0.000000
# 328    0.000000
# 329    0.000599
# 330    0.005873
# Name: 2->1Bytes, dtype: float64

# %%
nf_a['2->1Bytes'].loc[350:360]/mb
# Out:
# 350    1.191522
# 351    0.000000
# 352    0.000000
# 353    0.000118
# 354    0.000000
# 355    0.000000
# 356    0.000118
# 357    0.000000
# 358    0.000000
# 359    0.000236
# 360    0.000000
# Name: 2->1Bytes, dtype: float64

# %%
nf_a['2->1Bytes'].loc[319]/mb
# Out:
# 0.703837

# %%
print(nf_a['2->1Bytes'].max()/mb)
print(nf_b['2->1Bytes'].max()/mb)
# Out:
# 2.426757
# 1.17609

# %%
plt.plot(nf_a['1->2Bytes']/mb)
plt.plot(nf_b['1->2Bytes']/mb)
plt.xlabel("Index")
plt.ylabel("MB")
plt.title("Upload Rates of Netflix")
# Out:
# Text(0.5, 1.0, 'Upload Rates of Netflix')

# %%
plt.plot(yt_a['2->1Bytes']/mb)
plt.plot(yt_b['2->1Bytes']/mb)
plt.xlabel("Index")
plt.ylabel("MB")
plt.title("Download Rates of Youtube")
# Out:
# Text(0.5, 1.0, 'Download Rates of Youtube')

# %%
plt.plot(yt_a['1->2Bytes']/mb)
plt.plot(yt_b['1->2Bytes']/mb)
plt.xlabel("Index")
plt.ylabel("MB")
plt.title("Upload Rates of Youtube")
# Out:
# Text(0.5, 1.0, 'Upload Rates of Youtube')

# %%
plt.plot(ap_a['2->1Bytes']/mb)
plt.plot(ap_b['2->1Bytes']/mb)
plt.xlabel("Index")
plt.ylabel("MB")
plt.title("Download Rates of Amazon Prime")
# Out:
# Text(0.5, 1.0, 'Download Rates of Amazon Prime')

# %%
plt.plot(ap_a['1->2Bytes']/mb)
plt.plot(ap_b['1->2Bytes']/mb)
plt.xlabel("Index")
plt.ylabel("MB")
plt.title("Upload Rates of Amazon Prime")
# Out:
# Text(0.5, 1.0, 'Upload Rates of Amazon Prime')

# %%
sel = SelectFromModel(RandomForestClassifier(n_estimators = 100))
sel.fit(X_train, y_train)
sel.get_support()

# %%
selected_feat= X_train.columns[(sel.get_support())]
print(selected_feat)
len(selected_feat)
